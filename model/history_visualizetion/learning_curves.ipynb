# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
attn_history = pd.read_csv("./data/Attn_history.csv")
cross_history = pd.read_csv("./data/Cross_history.csv")

# %%
plt.plot(attn_history["loss"])
plt.plot(cross_history["loss"])
plt.legend(["Attn", "Cross"])
plt.title("Loss")
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
plt.plot(attn_history["recall@5"])
plt.plot(cross_history["recall@5"])
plt.legend(["Attn", "Cross"])
plt.title("Recall_5")
# Out:
# Text(0.5, 1.0, 'Recall_5')

# %%
plt.plot(attn_history["alignment"])
plt.plot(cross_history["alignment"])
plt.legend(["Attn", "Cross"])
plt.ylim(0, 0.5)
plt.title("Alignment")
# Out:
# Text(0.5, 1.0, 'Alignment')

# %%
plt.plot(attn_history["uniformnity"])
plt.plot(cross_history["uniformnity"])
plt.legend(["Attn", "Cross"])
plt.ylim(top=-2.75)
plt.title("Uniformnity")
# Out:
# Text(0.5, 1.0, 'Uniformnity')

# %%
plt.plot(attn_history["val_recall@5"])
plt.plot(cross_history["val_recall@5"])
plt.legend(["Attn", "Cross"])
plt.title("Val_Recall@5")
# Out:
# Text(0.5, 1.0, 'Val_Recall@5')
